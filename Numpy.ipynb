# %%
import numpy as np

# %%
##Data types and Attributes

# %%
a1 =np.array([1,2,4])
a1
# Out:
# array([1, 2, 4])

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
a2 =np.array([[1,2.8,3.7],[3,6.7,8.9]])
a3=np.array([[[1,2,3],
              [4,5,6],
              [4,7,8]],
           [ [10,11,12],
            [45,6,7],
            [3,8,5]]])

# %%
a2
# Out:
# array([[1. , 2.8, 3.7],
#        [3. , 6.7, 8.9]])

# %%
a3
# Out:
# array([[[ 1,  2,  3],
#         [ 4,  5,  6],
#         [ 4,  7,  8]],
#
#        [[10, 11, 12],
#         [45,  6,  7],
#         [ 3,  8,  5]]])

# %%
a1.shape
# Out:
# (3,)

# %%
a2.shape
# Out:
# (2, 3)

# %%
a3.shape
# Out:
# (2, 3, 3)

# %%
a1.ndim,a2.ndim,a3.ndim
# Out:
# (1, 2, 3)

# %%
a1.dtype
# Out:
# dtype('int32')

# %%
a2.dtype
# Out:
# dtype('float64')

# %%
a3.size
# Out:
# 18

# %%
a1.size,a2.size,a3.size
# Out:
# (3, 6, 18)

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
#create a dataframe from numpy array

# %%
import pandas as pd

# %%
df =pd.DataFrame(a2)
df
# Out:
#      0    1    2
# 0  1.0  2.8  3.7
# 1  3.0  6.7  8.9

# %%
df2=pd.DataFrame(a3)

df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-b8c0a31825bb> in <module>
# ----> 1 df2=pd.DataFrame(a3)
#       2
#       3 df2
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     462                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     463             else:
# --> 464                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     465
#     466         # For data is list-like, or Iterable (will consume into list)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     167     # by definition an array here
#     168     # the dtypes will be coerced to a single dtype
# --> 169     values = prep_ndarray(values, copy=copy)
#     170
#     171     if dtype is not None:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in prep_ndarray(values, copy)
#     293         values = values.reshape((values.shape[0], 1))
#     294     elif values.ndim != 2:
# --> 295         raise ValueError("Must pass 2-d input")
#     296
#     297     return values
#
# ValueError: Must pass 2-d input

# %%
# creating numpy arrays

# %%
sample_array= np.array([1,2,3])
sample_array

# %%
ones =np.ones((2,3))
ones

# %%
ones.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-0c6348b6a2a5> in <module>
# ----> 1 ones.dtype
#
# NameError: name 'ones' is not defined

# %%
type(ones)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-277c714b7dcf> in <module>
# ----> 1 type(ones)
#
# NameError: name 'ones' is not defined

# %%
zeros =np.zeros((2,3))
zeros
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
range_array =np.arange(0,10,2)
range_array
# Out:
# array([0, 2, 4, 6, 8])

# %%
random_array =np.random.randint(0,10,size=(3,5))

# %%
random_array
# Out:
# array([[3, 9, 3, 9, 6],
#        [6, 1, 5, 4, 7],
#        [7, 5, 5, 4, 7]])

# %%
random_array.shape
# Out:
# (3, 5)

# %%
random_array2=np.random.random((5,3))
random_array2
# Out:
# array([[0.28780462, 0.76942113, 0.46522606],
#        [0.40617403, 0.95684955, 0.3712227 ],
#        [0.96951752, 0.80349404, 0.91839509],
#        [0.22134639, 0.83196538, 0.43865453],
#        [0.85681004, 0.59210483, 0.26802538]])

# %%
random_array2.shape
# Out:
# (5, 3)

# %%
random_array3=np.random.rand(5,3)
random_array3
# Out:
# array([[0.69418003, 0.96320148, 0.7488721 ],
#        [0.83617376, 0.85337336, 0.30712411],
#        [0.50324075, 0.84785703, 0.83975125],
#        [0.41687406, 0.39418845, 0.72626147],
#        [0.4717023 , 0.26465756, 0.86180281]])

# %%
np.random.seed()

# %%
np.random.seed(seed=0)
random_array4 =np.random.randint(10,size=(5,3))
random_array4
# Out:
# array([[5, 0, 3],
#        [3, 7, 9],
#        [3, 5, 2],
#        [4, 7, 6],
#        [8, 8, 1]])

# %%
np.random.seed(seed=7)
random_array5=np.random.random((5,3))
random_array5
# Out:
# array([[0.07630829, 0.77991879, 0.43840923],
#        [0.72346518, 0.97798951, 0.53849587],
#        [0.50112046, 0.07205113, 0.26843898],
#        [0.4998825 , 0.67923   , 0.80373904],
#        [0.38094113, 0.06593635, 0.2881456 ]])

# %%
random_array5
# Out:
# array([[0.07630829, 0.77991879, 0.43840923],
#        [0.72346518, 0.97798951, 0.53849587],
#        [0.50112046, 0.07205113, 0.26843898],
#        [0.4998825 , 0.67923   , 0.80373904],
#        [0.38094113, 0.06593635, 0.2881456 ]])

# %%
#Manipulating and Comapring Arrys

# %%
a1
# Out:
# array([1, 2, 4])

# %%
ones
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-a0fa796ecd66> in <module>
# ----> 1 ones
#
# NameError: name 'ones' is not defined

# %%
ones =np.ones(3)

# %%
ones
# Out:
# array([1., 1., 1.])

# %%
a1 +ones
# Out:
# array([2., 3., 5.])

# %%
a1 - ones
# Out:
# array([0., 1., 3.])

# %%
a1* ones
# Out:
# array([1., 2., 4.])

# %%
a2
# Out:
# array([[1. , 2.8, 3.7],
#        [3. , 6.7, 8.9]])

# %%
a1*a2
# Out:
# array([[ 1. ,  5.6, 14.8],
#        [ 3. , 13.4, 35.6]])

# %%
a3
# Out:
# array([[[ 1,  2,  3],
#         [ 4,  5,  6],
#         [ 4,  7,  8]],
#
#        [[10, 11, 12],
#         [45,  6,  7],
#         [ 3,  8,  5]]])

# %%
a2*a3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-e78a3a07c1a0> in <module>
# ----> 1 a2*a3
#
# ValueError: operands could not be broadcast together with shapes (2,3) (2,3,3)

# %%
a2.reshape(2, 3,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-6ab7a1049bbb> in <module>
# ----> 1 a2.reshape(2, 3,3)
#
# ValueError: cannot reshape array of size 6 into shape (2,3,3)

# %%
 
 z = np.zeros((1, 3))

# %%
 z = np.zeros((1, 3), dtype=a2.dtype)

# %%
z
# Out:
# array([[0., 0., 0.]])

# %%
 np.c_[a2, z]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-35aa90e53357> in <module>
# ----> 1 np.c_[a2, z]
#
# ~\anaconda3\lib\site-packages\numpy\lib\index_tricks.py in __getitem__(self, key)
#     404                 objs[k] = objs[k].astype(final_dtype)
#     405
# --> 406         res = self.concatenate(tuple(objs), axis=axis)
#     407
#     408         if matrix:
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 2 and the array at index 1 has size 1

# %%
a2
# Out:
# array([[1. , 2.8, 3.7],
#        [3. , 6.7, 8.9]])

# %%
a1/ones
# Out:
# array([1., 2., 4.])

# %%
a2/a1
# Out:
# array([[1.   , 1.4  , 0.925],
#        [3.   , 3.35 , 2.225]])

# %%
a2//a1
# Out:
# array([[1., 1., 0.],
#        [3., 3., 2.]])

# %%
a2**2
# Out:
# array([[ 1.  ,  7.84, 13.69],
#        [ 9.  , 44.89, 79.21]])

# %%
a1**2
# Out:
# array([ 1,  4, 16], dtype=int32)

# %%
a1**3
# Out:
# array([ 1,  8, 64], dtype=int32)

# %%
np.square(a2)
# Out:
# array([[ 1.  ,  7.84, 13.69],
#        [ 9.  , 44.89, 79.21]])

# %%
np.add(a1,ones)
# Out:
# array([2., 3., 5.])

# %%
a1%a2
# Out:
# array([[0. , 2. , 0.3],
#        [1. , 2. , 4. ]])

# %%
np.exp(a1)
# Out:
# array([ 2.71828183,  7.3890561 , 54.59815003])

# %%
np.log(a2)
# Out:
# array([[0.        , 1.02961942, 1.30833282],
#        [1.09861229, 1.90210753, 2.18605128]])

# %% [markdown]
# ###Aggregation

# %%
listy_list = [1,2,3]

# %%
type(listy_list)
# Out:
# list

# %%
sum(listy_list)
# Out:
# 6

# %%
a1
# Out:
# array([1, 2, 4])

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
sum(a1)
# Out:
# 7

# %%
np.sum(a1 )
# Out:
# 7

# %%
#use python methods on pythond data types , use numpy methods on numpy data types

# %%
massive_array =np.random.random(100000)
massive_array.size
# Out:
# 100000

# %%
massive_array[:10]
# Out:
# array([0.90959353, 0.21338535, 0.45212396, 0.93120602, 0.02489923,
#        0.60054892, 0.9501295 , 0.23030288, 0.54848992, 0.90912837])

# %%
#python sum
# %timeit sum(massive_array)

#numpy sum
# %timeit np.sum(massive_array)
# Out:
# 16.5 ms ± 1.45 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 44.2 µs ± 4.6 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit sum(massive_array)
# %timeit np.sum(massive_array)
# Out:
# 15.9 ms ± 907 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 41.9 µs ± 1.16 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
a2
# Out:
# array([[1. , 2.8, 3.7],
#        [3. , 6.7, 8.9]])

# %%
np.mean(a2)
# Out:
# 4.3500000000000005

# %%
np.max(a2
      )
# Out:
# 8.9

# %%
np.std(a2)
# Out:
# 2.648741839691693

# %%
np.var(a2)
# Out:
# 7.015833333333333

# %%
np.sqrt(np.var(a2))
# Out:
# 2.648741839691693

# %%
###Demo of std and var

# %%
high_var_array =np.array([1,100,200,40000,50000])
low_var_array =np.array([2,4,6,8,10])

# %%
np.var(high_var_array)
# Out:
# 493839176.16

# %%
np.var(low_var_array)
# Out:
# 8.0

# %%
np.std(high_var_array),np.std(low_var_array)
# Out:
# (22222.492573066596, 2.8284271247461903)

# %%
np.mean(high_var_array),np.mean(low_var_array)
# Out:
# (18060.2, 6.0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(high_var_array)
# Out:
# (array([3., 0., 0., 0., 0., 0., 0., 1., 0., 1.]),
#  array([1.00000e+00, 5.00090e+03, 1.00008e+04, 1.50007e+04, 2.00006e+04,
#         2.50005e+04, 3.00004e+04, 3.50003e+04, 4.00002e+04, 4.50001e+04,
#         5.00000e+04]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(low_var_array)
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 1., 0., 1.]),
#  array([ 2. ,  2.8,  3.6,  4.4,  5.2,  6. ,  6.8,  7.6,  8.4,  9.2, 10. ]),
#  <a list of 10 Patch objects>)

# %%
#Reshapinh & TRANSPOSING

# %%
a3.shape
# Out:
# (2, 3, 3)

# %% [markdown]
# ##

# %%
a2.a3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-6dc89a8e9f43> in <module>
# ----> 1 a2.a3
#
# AttributeError: 'numpy.ndarray' object has no attribute 'a3'

# %%
a2*a3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-e78a3a07c1a0> in <module>
# ----> 1 a2*a3
#
# ValueError: operands could not be broadcast together with shapes (2,3) (2,3,3)

# %%
a4=a2.reshape(2,3,1)

# %%
a2.shape
# Out:
# (2, 3)

# %%
a3.shape
# Out:
# (2, 3, 3)

# %%
a4
# Out:
# array([[[1. ],
#         [2.8],
#         [3.7]],
#
#        [[3. ],
#         [6.7],
#         [8.9]]])

# %%
a4*a3
# Out:
# array([[[  1. ,   2. ,   3. ],
#         [ 11.2,  14. ,  16.8],
#         [ 14.8,  25.9,  29.6]],
#
#        [[ 30. ,  33. ,  36. ],
#         [301.5,  40.2,  46.9],
#         [ 26.7,  71.2,  44.5]]])

# %%
###Transpose

# %%
a2.T
# Out:
# array([[1. , 3. ],
#        [2.8, 6.7],
#        [3.7, 8.9]])

# %%
a2.T.shape
# Out:
# (3, 2)

# %% [markdown]
# ##

# %%
a2
# Out:
# array([[1. , 2.8, 3.7],
#        [3. , 6.7, 8.9]])

# %%
a3.shape
# Out:
# (2, 3, 3)

# %%
a3.T
# Out:
# array([[[ 1, 10],
#         [ 4, 45],
#         [ 4,  3]],
#
#        [[ 2, 11],
#         [ 5,  6],
#         [ 7,  8]],
#
#        [[ 3, 12],
#         [ 6,  7],
#         [ 8,  5]]])

# %%
a3.T.shape
# Out:
# (3, 3, 2)

# %%
##Dot Product

# %%
np.random.seed(0)

mat1 =np.random.randint(10,size=(5,3))
mat2=np.random.randint(10,size=(5,3))

# %% [markdown]
# mat1,mat2

# %%
mat1,mat2
# Out:
# (array([[5, 0, 3],
#         [3, 7, 9],
#         [3, 5, 2],
#         [4, 7, 6],
#         [8, 8, 1]]),
#  array([[6, 7, 7],
#         [8, 1, 5],
#         [9, 8, 9],
#         [4, 3, 0],
#         [3, 5, 0]]))

# %%
#eleemnt wise product
mat1*mat2
# Out:
# array([[30,  0, 21],
#        [24,  7, 45],
#        [27, 40, 18],
#        [16, 21,  0],
#        [24, 40,  0]])

# %%
#dot product
np.dot(mat1,mat2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-0ef043dda00d> in <module>
#       1 #dot product
# ----> 2 np.dot(mat1,mat2)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (5,3) and (5,3) not aligned: 3 (dim 1) != 5 (dim 0)

# %%
mat1.shape,mat2.shape
# Out:
# ((5, 3), (5, 3))

# %%
np.dot(mat1,mat2.T)
# Out:
# array([[ 51,  55,  72,  20,  15],
#        [130,  76, 164,  33,  44],
#        [ 67,  39,  85,  27,  34],
#        [115,  69, 146,  37,  47],
#        [111,  77, 145,  56,  64]])
