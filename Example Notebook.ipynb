# %% [markdown]
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %%
a= 5

# %%
a=6

# %%
print(a)
# Out:
# 6

# %% [markdown]
# #Heart Disease Project

# %% [markdown]
# this project about patients heart diseases

# %%
import pandas as pd

# %% [markdown]
# the following table shows heart dieseis

# %%
df = pd.read_csv("11.3 heart-disease.csv")
df.head(50)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
df.target.value_counts().plot(kind="bar")

# %% [markdown]
#                                     ![](6-step-ml-framework.png)

# %% [markdown]
# ##problem definition`

# %% [markdown]
# ##2 Data insert

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6A59-8E60
#
#  Directory of C:\Users\Pasindu Thiwanka\Desktop\Self Study\Python\Machine Learning\sample_project_1
#
# 2020-08-22  05:43 PM    <DIR>          .
# 2020-08-22  05:43 PM    <DIR>          ..
# 2020-08-22  04:55 PM    <DIR>          .ipynb_checkpoints
# 2020-08-22  05:33 PM            11,328 11.3 heart-disease.csv
# 2020-08-22  05:41 PM           332,025 11.4 6-step-ml-framework.png
# 2020-08-22  04:28 PM    <DIR>          env
# 2020-08-22  05:43 PM            41,423 Example Notebook.ipynb
# 2020-08-22  04:42 PM             6,676 Untitled.ipynb
#                4 File(s)        391,452 bytes
#                4 Dir(s)  150,354,341,888 bytes free
