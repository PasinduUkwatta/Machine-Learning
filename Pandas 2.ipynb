# %%
import pandas as pd
animals =pd.Series(["cat","dog","lion","snake","panda"])
animals
# Out:
# 0      cat
# 1      dog
# 2     lion
# 3    snake
# 4    panda
# dtype: object

# %%
animals.loc[3]
# Out:
# 'snake'

# %%
animals.iloc[3]
# Out:
# 'snake'

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 1     dog
# 2    lion
# dtype: object

# %%
car_sales_missing=pd.read_csv("9.2 car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"]=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing

# %%
car_sales_missing.dropna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-e531f05d7f15> in <module>
# ----> 1 car_sales_missing.dropna()
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
car_sales_missing_drop

# %%
car_sales_missing

# %%
car_sales=pd.read_csv("9.2 car-sales-missing-data.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
fule_ecomny=[1,5,3,2,7,6,4,6,7,8]
car_sales["Fule Economy"] =fule_ecomny
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price  Fule Economy
# 0  Toyota  White  150043.0    4.0   $4,000             1
# 1   Honda    Red   87899.0    4.0   $5,000             5
# 2  Toyota   Blue       NaN    3.0   $7,000             3
# 3     BMW  Black   11179.0    5.0  $22,000             2
# 4  Nissan  White  213095.0    4.0   $3,500             7
# 5  Toyota  Green       NaN    4.0   $4,500             6
# 6   Honda    NaN       NaN    4.0   $7,500             4
# 7   Honda   Blue       NaN    4.0      NaN             6
# 8  Toyota  White   60000.0    NaN      NaN             7
# 9     NaN  White   31600.0    4.0   $9,700             8

# %%
car_sales.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price  Fule Economy
# 0  Toyota  White  150043.0    4.0   $4,000             1
# 1   Honda    Red   87899.0    4.0   $5,000             5
# 3     BMW  Black   11179.0    5.0  $22,000             2
# 4  Nissan  White  213095.0    4.0   $3,500             7

# %%
car_sales["Total Fule Used"] = car_sales["Odometer"]*car_sales["Fule Economy"]
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price  Fule Economy  Total Fule Used
# 0  Toyota  White  150043.0    4.0   $4,000             1         150043.0
# 1   Honda    Red   87899.0    4.0   $5,000             5         439495.0
# 2  Toyota   Blue       NaN    3.0   $7,000             3              NaN
# 3     BMW  Black   11179.0    5.0  $22,000             2          22358.0
# 4  Nissan  White  213095.0    4.0   $3,500             7        1491665.0
# 5  Toyota  Green       NaN    4.0   $4,500             6              NaN
# 6   Honda    NaN       NaN    4.0   $7,500             4              NaN
# 7   Honda   Blue       NaN    4.0      NaN             6              NaN
# 8  Toyota  White   60000.0    NaN      NaN             7         420000.0
# 9     NaN  White   31600.0    4.0   $9,700             8         252800.0

# %%
car_sales.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price  Fule Economy  Total Fule Used
# 0  Toyota  White  150043.0    4.0   $4,000             1         150043.0
# 1   Honda    Red   87899.0    4.0   $5,000             5         439495.0
# 3     BMW  Black   11179.0    5.0  $22,000             2          22358.0
# 4  Nissan  White  213095.0    4.0   $3,500             7        1491665.0

# %%
car_sales["Number Of Wheels"]=4
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price  Fule Economy  Total Fule Used  \
# 0  Toyota  White  150043.0    4.0   $4,000             1         150043.0
# 1   Honda    Red   87899.0    4.0   $5,000             5         439495.0
# 2  Toyota   Blue       NaN    3.0   $7,000             3              NaN
# 3     BMW  Black   11179.0    5.0  $22,000             2          22358.0
# 4  Nissan  White  213095.0    4.0   $3,500             7        1491665.0
# 5  Toyota  Green       NaN    4.0   $4,500             6              NaN
# 6   Honda    NaN       NaN    4.0   $7,500             4              NaN
# 7   Honda   Blue       NaN    4.0      NaN             6              NaN
# 8  Toyota  White   60000.0    NaN      NaN             7         420000.0
# 9     NaN  White   31600.0    4.0   $9,700             8         252800.0
#
#    Number Of Wheels
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# 5                 4
# ...

# %%
car_sales.dtypes
# Out:
# Make                 object
# Colour               object
# Odometer            float64
# Doors               float64
# Price                object
# Fule Economy          int64
# Total Fule Used     float64
# Number Of Wheels      int64
# dtype: object

# %%
car_sales=car_sales.dropna()

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price  Fule Economy  Total Fule Used  \
# 0  Toyota  White  150043.0    4.0   $4,000             1         150043.0
# 1   Honda    Red   87899.0    4.0   $5,000             5         439495.0
# 3     BMW  Black   11179.0    5.0  $22,000             2          22358.0
# 4  Nissan  White  213095.0    4.0   $3,500             7        1491665.0
#
#    Number Of Wheels
# 0                 4
# 1                 4
# 3                 4
# 4                 4

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer  Doors    Price  Fule Economy  Total Fule Used  \
# 0  Toyota  White  150043.0    4.0   $4,000             1         150043.0
# 1   Honda    Red   87899.0    4.0   $5,000             5         439495.0
# 4  Nissan  White  213095.0    4.0   $3,500             7        1491665.0
# 3     BMW  Black   11179.0    5.0  $22,000             2          22358.0
#
#    Number Of Wheels
# 0                 4
# 1                 4
# 4                 4
# 3                 4

# %%
car_sales_shuffle=car_sales.sample(frac=1)

# %%
car_sales_shuffle
# Out:
#      Make Colour  Odometer  Doors    Price  Fule Economy  Total Fule Used  \
# 4  Nissan  White  213095.0    4.0   $3,500             7        1491665.0
# 3     BMW  Black   11179.0    5.0  $22,000             2          22358.0
# 0  Toyota  White  150043.0    4.0   $4,000             1         150043.0
# 1   Honda    Red   87899.0    4.0   $5,000             5         439495.0
#
#    Number Of Wheels
# 4                 4
# 3                 4
# 0                 4
# 1                 4

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price  Fule Economy  Total Fule Used  \
# 0  Toyota  White  150043.0    4.0   $4,000             1         150043.0
# 1   Honda    Red   87899.0    4.0   $5,000             5         439495.0
# 3     BMW  Black   11179.0    5.0  $22,000             2          22358.0
# 4  Nissan  White  213095.0    4.0   $3,500             7        1491665.0
#
#    Number Of Wheels
# 0                 4
# 1                 4
# 3                 4
# 4                 4

# %%
car_sales["Odometer"]=car_sales["Odometer"].apply(lambda x: x/1.6)
car_sales
# Out:
# <ipython-input-58-a8529dd32f4f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales["Odometer"]=car_sales["Odometer"].apply(lambda x: x/1.6)
#      Make Colour     Odometer  Doors    Price  Fule Economy  Total Fule Used  \
# 0  Toyota  White  5861.054688    4.0   $4,000             1         150043.0
# 1   Honda    Red  3433.554688    4.0   $5,000             5         439495.0
# 3     BMW  Black   436.679688    5.0  $22,000             2          22358.0
# 4  Nissan  White  8324.023438    4.0   $3,500             7        1491665.0
#
#    Number Of Wheels
# 0                 4
# 1                 4
# 3                 4
# 4                 4
